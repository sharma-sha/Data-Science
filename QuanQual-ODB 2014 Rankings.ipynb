# %%
import pandas as pd

# %%
dataset=pd.read_csv("ODB-2014-Rankings.csv")
dataset
# Out:
#     Year                      Region               Income ISO2 ISO3  ODB-Rank  \
# 0   2014  Middle East & North Africa          High income   AE  ARE        52
# 1   2014   Latin America & Caribbean  Upper middle income   AR  ARG        36
# 2   2014         East Asia & Pacific          High income   AU  AUS        10
# 3   2014       Europe & Central Asia          High income   AT  AUT        15
# 4   2014       Europe & Central Asia          High income   BE  BEL        27
# ..   ...                         ...                  ...  ...  ...       ...
# 81  2014         East Asia & Pacific  Lower middle income   VN  VNM        57
# 82  2014  Middle East & North Africa  Lower middle income   YE  YEM        82
# 83  2014          Sub-Saharan Africa  Upper middle income   ZA  ZAF        41
# 84  2014          Sub-Saharan Africa  Lower middle income   ZM  ZMB        78
# 85  2014          Sub-Saharan Africa           Low income   ZW  ZWE        76
#
#          Country  ODB-Score  Readiness  Implementation  ...  \
# 0            UAE  -0.113555  -0.011659       -0.480576  ...
# 1      Argentina   0.023207  -0.174486        0.187631  ...
# 2      Australia   0.434557   1.185518        1.657688  ...
# 3        Austria   0.310956   0.906397        0.421504  ...
# 4        Belgium   0.169248   1.013088       -0.113062  ...
# ..           ...        ...        ...             ...  ...
# 81       Vietnam  -0.197238  -1.159286       -0.330230  ...
# 82         Yemen  -0.353913  -1.289778       -1.198900  ...
# 83  South Africa  -0.039921  -0.171404       -0.062947  ...
# 84        Zambia  -0.329643  -1.045805       -1.132079  ...
# 85      Zimbabwe  -0.305403  -1.040686       -1.031848  ...
#
#     Impact_Economic-Scaled    HDI  G20   G7  GDP-Per-Capita-Current-USD  \
# 0                        0  0.827  NaN  NaN                         NaN
# 1                       20  0.808  G20  NaN                14715.180020
# 2                       40  0.933  G20  NaN                67468.068710
# 3                       59  0.881  NaN  NaN                49053.822900
# 4                       61  0.881  NaN  NaN                45387.175530
# ..                     ...    ...  ...  ...                         ...
# 81                       7  0.638  NaN  NaN                 1910.533073
# 82                       6  0.500  NaN  NaN                 1473.099564
# 83                       0  0.658  G20  NaN                 6617.911609
# 84                       0  0.561  NaN  NaN                 1539.601731
# 85                       0  0.492  NaN  NaN                  904.755015
#
#     2013-Rank  2013-ODB-Scaled  ODB Change  Rank Change  \
# 0         NaN              NaN         NaN          NaN
# 1        31.0            35.00        0.71         -5.0
# 2         7.0            67.68        0.65         -3.0
# 3        18.0            46.03       12.49          3.0
# 4        31.0            34.80       12.49          4.0
# ..        ...              ...         ...          ...
# 81        NaN              NaN         NaN          NaN
# 82       73.0             4.69        1.11         -9.0
# 83       52.0            19.20       11.50         11.0
# 84       75.0             4.23        3.50         -3.0
# 85       73.0             5.30        4.35         -3.0
#
#                    Cluster
# 0     One sided initiative
# 1   Emerging and advancing
# 2            High capacity
# 3            High capacity
# 4            High capacity
# ..                     ...
# 81    Capacity constrained
# 82    Capacity constrained
# 83  Emerging and advancing
# 84    Capacity constrained
# 85    Capacity constrained
#
# [86 rows x 45 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 45 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Year                            86 non-null     int64
#  1   Region                          86 non-null     object
#  2   Income                          86 non-null     object
#  3   ISO2                            85 non-null     object
#  4   ISO3                            86 non-null     object
#  5   ODB-Rank                        86 non-null     int64
#  6   Country                         86 non-null     object
#  7   ODB-Score                       86 non-null     float64
#  8   Readiness                       86 non-null     float64
#  9   Implementation                  86 non-null     float64
#  10  Impact                          86 non-null     float64
#  11  ODB-Scaled                      86 non-null     float64
#  12  Readiness-Scaled                86 non-null     int64
#  13  Implementation-Scaled           86 non-null     int64
#  14  Impact-Scaled                   86 non-null     int64
#  15  Readiness_Government            86 non-null     float64
#  16  Readiness_Government-Scaled     86 non-null     int64
#  17  Readiness_Citizens              86 non-null     float64
#  18  Readiness_Citizens-Scaled       86 non-null     int64
#  19  Readiness_Entrepreneurs         86 non-null     float64
#  20  Readiness_Entrepreneurs-Scaled  86 non-null     int64
#  21  Readiness-Rank                  86 non-null     int64
#  22  Datasets_Innovation             86 non-null     int64
#  23  Datasets_Social_Policy          86 non-null     int64
#  24  Datasets_Accountability         86 non-null     int64
#  25  Datasets_Average                86 non-null     float64
#  26  Datasets_Normalised             86 non-null     float64
#  27  Implementation.1                86 non-null     float64
#  28  Implementation-Scaled.1         86 non-null     int64
#  29  Implementation-Rank             86 non-null     int64
#  30  Impact_Political                86 non-null     float64
#  31  Impact_Political-Scaled         86 non-null     int64
#  32  Impact_Social                   86 non-null     float64
#  33  Impact_Social-Scaled            86 non-null     int64
#  34  Impact_Economic                 86 non-null     float64
#  35  Impact_Economic-Scaled          86 non-null     int64
#  36  HDI                             86 non-null     float64
#  37  G20                             19 non-null     object
#  38  G7                              7 non-null      object
#  39  GDP-Per-Capita-Current-USD      84 non-null     float64
#  40  2013-Rank                       75 non-null     float64
#  41  2013-ODB-Scaled                 75 non-null     float64
#  42  ODB Change                      75 non-null     float64
#  43  Rank Change                     75 non-null     float64
#  44  Cluster                         86 non-null     object
# dtypes: float64(20), int64(17), object(8)
# memory usage: 30.4+ KB

# %%
#dtypes: float64(20), int64(17), object(8)

# %%
dataset.columns
# Out:
# Index(['Year', 'Region', 'Income', 'ISO2', 'ISO3', 'ODB-Rank', 'Country',
#        'ODB-Score', 'Readiness', 'Implementation', 'Impact', 'ODB-Scaled',
#        'Readiness-Scaled', 'Implementation-Scaled', 'Impact-Scaled',
#        'Readiness_Government', 'Readiness_Government-Scaled',
#        'Readiness_Citizens', 'Readiness_Citizens-Scaled',
#        'Readiness_Entrepreneurs', 'Readiness_Entrepreneurs-Scaled',
#        'Readiness-Rank', 'Datasets_Innovation', 'Datasets_Social_Policy',
#        'Datasets_Accountability', 'Datasets_Average', 'Datasets_Normalised',
#        'Implementation.1', 'Implementation-Scaled.1', 'Implementation-Rank',
#        'Impact_Political', 'Impact_Political-Scaled', 'Impact_Social',
#        'Impact_Social-Scaled', 'Impact_Economic', 'Impact_Economic-Scaled',
#        'HDI', 'G20', 'G7', 'GDP-Per-Capita-Current-USD', '2013-Rank',
#        '2013-ODB-Scaled', 'ODB Change', 'Rank Change', 'Cluster'],
#       dtype='object')

# %%
dir(dataset)
# Out:
# ['Cluster',
#  'Country',
#  'Datasets_Accountability',
#  'Datasets_Average',
#  'Datasets_Innovation',
#  'Datasets_Normalised',
#  'Datasets_Social_Policy',
#  'G20',
#  'G7',
#  'HDI',
#  'ISO2',
#  'ISO3',
#  'Impact',
#  'Impact_Economic',
#  'Impact_Political',
#  'Impact_Social',
#  'Implementation',
#  'Income',
#  'Readiness',
#  'Readiness_Citizens',
#  'Readiness_Entrepreneurs',
#  'Readiness_Government',
#  'Region',
#  'T',
#  'Year',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pandas_priority__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmatmul__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__weakref__',
#  '__xor__',
#  '_accessors',
#  '_accum_func',
#  '_agg_examples_doc',
#  '_agg_see_also_doc',
#  '_align_for_op',
#  '_align_frame',
#  '_align_series',
#  '_append',
#  '_arith_method',
#  '_arith_method_with_reindex',
#  '_as_manager',
#  '_attrs',
#  '_box_col_values',
#  '_can_fast_transpose',
#  '_check_inplace_and_allows_duplicate_labels',
#  '_check_is_chained_assignment_possible',
#  '_check_label_or_level_ambiguity',
#  '_check_setitem_copy',
#  '_clear_item_cache',
#  '_clip_with_one_bound',
#  '_clip_with_scalar',
#  '_cmp_method',
#  '_combine_frame',
#  '_consolidate',
#  '_consolidate_inplace',
#  '_construct_axes_dict',
#  '_construct_result',
#  '_constructor',
#  '_constructor_from_mgr',
#  '_constructor_sliced',
#  '_constructor_sliced_from_mgr',
#  '_create_data_for_split_and_tight_to_dict',
#  '_data',
#  '_deprecate_downcast',
#  '_dir_additions',
#  '_dir_deletions',
#  '_dispatch_frame_op',
#  '_drop_axis',
#  '_drop_labels_or_levels',
#  '_ensure_valid_index',
#  '_find_valid_index',
#  '_flags',
#  '_flex_arith_method',
#  '_flex_cmp_method',
#  '_from_arrays',
#  '_from_mgr',
#  '_get_agg_axis',
#  '_get_axis',
#  '_get_axis_name',
#  '_get_axis_number',
#  '_get_axis_resolvers',
#  '_get_block_manager_axis',
#  '_get_bool_data',
#  '_get_cleaned_column_resolvers',
#  '_get_column_array',
#  '_get_index_resolvers',
#  '_get_item_cache',
#  '_get_label_or_level_values',
#  '_get_numeric_data',
#  '_get_value',
#  '_get_values_for_csv',
#  '_getitem_bool_array',
#  '_getitem_multilevel',
#  '_getitem_nocopy',
#  '_getitem_slice',
#  '_gotitem',
#  '_hidden_attrs',
#  '_indexed_same',
#  '_info_axis',
#  '_info_axis_name',
#  '_info_axis_number',
#  '_info_repr',
#  '_init_mgr',
#  '_inplace_method',
#  '_internal_names',
#  '_internal_names_set',
#  '_is_copy',
#  '_is_homogeneous_type',
#  '_is_label_or_level_reference',
#  '_is_label_reference',
#  '_is_level_reference',
#  '_is_mixed_type',
#  '_is_view',
#  '_is_view_after_cow_rules',
#  '_iset_item',
#  '_iset_item_mgr',
#  '_iset_not_inplace',
#  '_item_cache',
#  '_iter_column_arrays',
#  '_ixs',
#  '_logical_func',
#  '_logical_method',
#  '_maybe_align_series_as_frame',
#  '_maybe_cache_changed',
#  '_maybe_update_cacher',
#  '_metadata',
#  '_mgr',
#  '_min_count_stat_function',
#  '_needs_reindex_multi',
#  '_pad_or_backfill',
#  '_protect_consolidate',
#  '_reduce',
#  '_reduce_axis1',
#  '_reindex_axes',
#  '_reindex_multi',
#  '_reindex_with_indexers',
#  '_rename',
#  '_replace_columnwise',
#  '_repr_data_resource_',
#  '_repr_fits_horizontal_',
#  '_repr_fits_vertical_',
#  '_repr_html_',
#  '_repr_latex_',
#  '_reset_cache',
#  '_reset_cacher',
#  '_sanitize_column',
#  '_series',
#  '_set_axis',
#  '_set_axis_name',
#  '_set_axis_nocheck',
#  '_set_is_copy',
#  '_set_item',
#  '_set_item_frame_value',
#  '_set_item_mgr',
#  '_set_value',
#  '_setitem_array',
#  '_setitem_frame',
#  '_setitem_slice',
#  '_shift_with_freq',
#  '_should_reindex_frame_op',
#  '_slice',
#  '_stat_function',
#  '_stat_function_ddof',
#  '_take_with_is_copy',
#  '_to_dict_of_blocks',
#  '_to_latex_via_styler',
#  '_typ',
#  '_update_inplace',
#  '_validate_dtype',
#  '_values',
#  '_where',
#  'abs',
#  'add',
#  'add_prefix',
#  'add_suffix',
#  'agg',
#  'aggregate',
#  'align',
#  'all',
#  'any',
#  'apply',
#  'applymap',
#  'asfreq',
#  'asof',
#  'assign',
#  'astype',
#  'at',
#  'at_time',
#  'attrs',
#  'axes',
#  'backfill',
#  'between_time',
#  'bfill',
#  'bool',
#  'boxplot',
#  'clip',
#  'columns',
#  'combine',
#  'combine_first',
#  'compare',
#  'convert_dtypes',
#  'copy',
#  'corr',
#  'corrwith',
#  'count',
#  'cov',
#  'cummax',
#  'cummin',
#  'cumprod',
#  'cumsum',
#  'describe',
#  'diff',
#  'div',
#  'divide',
#  'dot',
#  'drop',
#  'drop_duplicates',
#  'droplevel',
#  'dropna',
#  'dtypes',
#  'duplicated',
#  'empty',
#  'eq',
#  'equals',
#  'eval',
#  'ewm',
#  'expanding',
#  'explode',
#  'ffill',
#  'fillna',
#  'filter',
#  'first',
#  'first_valid_index',
#  'flags',
#  'floordiv',
#  'from_dict',
#  'from_records',
#  'ge',
#  'get',
#  'groupby',
#  'gt',
#  'head',
#  'hist',
#  'iat',
#  'idxmax',
#  'idxmin',
#  'iloc',
#  'index',
#  'infer_objects',
#  'info',
#  'insert',
#  'interpolate',
#  'isetitem',
#  'isin',
#  'isna',
#  'isnull',
#  'items',
#  'iterrows',
#  'itertuples',
#  'join',
#  'keys',
#  'kurt',
#  'kurtosis',
#  'last',
#  'last_valid_index',
#  'le',
#  'loc',
#  'lt',
#  'map',
#  'mask',
#  'max',
#  'mean',
#  'median',
#  'melt',
#  'memory_usage',
#  'merge',
#  'min',
#  'mod',
#  'mode',
#  'mul',
#  'multiply',
#  'ndim',
#  'ne',
#  'nlargest',
#  'notna',
#  'notnull',
#  'nsmallest',
#  'nunique',
#  'pad',
#  'pct_change',
#  'pipe',
#  'pivot',
#  'pivot_table',
#  'plot',
#  'pop',
#  'pow',
#  'prod',
#  'product',
#  'quantile',
#  'query',
#  'radd',
#  'rank',
#  'rdiv',
#  'reindex',
#  'reindex_like',
#  'rename',
#  'rename_axis',
#  'reorder_levels',
#  'replace',
#  'resample',
#  'reset_index',
#  'rfloordiv',
#  'rmod',
#  'rmul',
#  'rolling',
#  'round',
#  'rpow',
#  'rsub',
#  'rtruediv',
#  'sample',
#  'select_dtypes',
#  'sem',
#  'set_axis',
#  'set_flags',
#  'set_index',
#  'shape',
#  'shift',
#  'size',
#  'skew',
#  'sort_index',
#  'sort_values',
#  'squeeze',
#  'stack',
#  'std',
#  'style',
#  'sub',
#  'subtract',
#  'sum',
#  'swapaxes',
#  'swaplevel',
#  'tail',
#  'take',
#  'to_clipboard',
#  'to_csv',
#  'to_dict',
#  'to_excel',
#  'to_feather',
#  'to_gbq',
#  'to_hdf',
#  'to_html',
#  'to_json',
#  'to_latex',
#  'to_markdown',
#  'to_numpy',
#  'to_orc',
#  'to_parquet',
#  'to_period',
#  'to_pickle',
#  'to_records',
#  'to_sql',
#  'to_stata',
#  'to_string',
#  'to_timestamp',
#  'to_xarray',
#  'to_xml',
#  'transform',
#  'transpose',
#  'truediv',
#  'truncate',
#  'tz_convert',
#  'tz_localize',
#  'unstack',
#  'update',
#  'value_counts',
#  'values',
#  'var',
#  'where',
#  'xs']

# %%
dataset.dtypes
# Out:
# Year                                int64
# Region                             object
# Income                             object
# ISO2                               object
# ISO3                               object
# ODB-Rank                            int64
# Country                            object
# ODB-Score                         float64
# Readiness                         float64
# Implementation                    float64
# Impact                            float64
# ODB-Scaled                        float64
# Readiness-Scaled                    int64
# Implementation-Scaled               int64
# Impact-Scaled                       int64
# Readiness_Government              float64
# Readiness_Government-Scaled         int64
# Readiness_Citizens                float64
# Readiness_Citizens-Scaled           int64
# Readiness_Entrepreneurs           float64
# Readiness_Entrepreneurs-Scaled      int64
# Readiness-Rank                      int64
# Datasets_Innovation                 int64
# Datasets_Social_Policy              int64
# Datasets_Accountability             int64
# Datasets_Average                  float64
# Datasets_Normalised               float64
# Implementation.1                  float64
# Implementation-Scaled.1             int64
# Implementation-Rank                 int64
# Impact_Political                  float64
# Impact_Political-Scaled             int64
# Impact_Social                     float64
# Impact_Social-Scaled                int64
# Impact_Economic                   float64
# Impact_Economic-Scaled              int64
# HDI                               float64
# G20                                object
# G7                                 object
# GDP-Per-Capita-Current-USD        float64
# 2013-Rank                         float64
# 2013-ODB-Scaled                   float64
# ODB Change                        float64
# Rank Change                       float64
# Cluster                            object
# dtype: object

# %%
dataset["Rank Change"].dtypes
# Out:
# dtype('float64')

# %%
dataset.dtypes
# Out:
# Year                                int64
# Region                             object
# Income                             object
# ISO2                               object
# ISO3                               object
# ODB-Rank                            int64
# Country                            object
# ODB-Score                         float64
# Readiness                         float64
# Implementation                    float64
# Impact                            float64
# ODB-Scaled                        float64
# Readiness-Scaled                    int64
# Implementation-Scaled               int64
# Impact-Scaled                       int64
# Readiness_Government              float64
# Readiness_Government-Scaled         int64
# Readiness_Citizens                float64
# Readiness_Citizens-Scaled           int64
# Readiness_Entrepreneurs           float64
# Readiness_Entrepreneurs-Scaled      int64
# Readiness-Rank                      int64
# Datasets_Innovation                 int64
# Datasets_Social_Policy              int64
# Datasets_Accountability             int64
# Datasets_Average                  float64
# Datasets_Normalised               float64
# Implementation.1                  float64
# Implementation-Scaled.1             int64
# Implementation-Rank                 int64
# Impact_Political                  float64
# Impact_Political-Scaled             int64
# Impact_Social                     float64
# Impact_Social-Scaled                int64
# Impact_Economic                   float64
# Impact_Economic-Scaled              int64
# HDI                               float64
# G20                                object
# G7                                 object
# GDP-Per-Capita-Current-USD        float64
# 2013-Rank                         float64
# 2013-ODB-Scaled                   float64
# ODB Change                        float64
# Rank Change                       float64
# Cluster                            object
# dtype: object

# %%
for columnsName in dataset.columns:
    print(columnsName)
# Out:
# Year
# Region
# Income
# ISO2
# ISO3
# ODB-Rank
# Country
# ODB-Score
# Readiness
# Implementation
# Impact
# ODB-Scaled
# Readiness-Scaled
# Implementation-Scaled
# Impact-Scaled
# Readiness_Government
# Readiness_Government-Scaled
# Readiness_Citizens
# Readiness_Citizens-Scaled
# Readiness_Entrepreneurs
# Readiness_Entrepreneurs-Scaled
# Readiness-Rank
# Datasets_Innovation
# Datasets_Social_Policy
# Datasets_Accountability
# Datasets_Average
# Datasets_Normalised
# Implementation.1
# Implementation-Scaled.1
# Implementation-Rank
# Impact_Political
# Impact_Political-Scaled
# Impact_Social
# Impact_Social-Scaled
# Impact_Economic
# Impact_Economic-Scaled
# HDI
# G20
# G7
# GDP-Per-Capita-Current-USD
# 2013-Rank
# 2013-ODB-Scaled
# ODB Change
# Rank Change
# Cluster

# %%
if (dataset["Rank Change"].dtype=='O'):
    print("qual")
else:
    print("quan")
# Out:
# quan

# %%
qual=[]
quan=[]
for columnName in dataset.columns:
    print(columnName)
    if(dataset[columnName].dtype=='O'):
        #print("qual")
        qual.append(columnName)
    else:
        #print("quan")
        quan.append(columnName)
# Out:
# Year
# Region
# Income
# ISO2
# ISO3
# ODB-Rank
# Country
# ODB-Score
# Readiness
# Implementation
# Impact
# ODB-Scaled
# Readiness-Scaled
# Implementation-Scaled
# Impact-Scaled
# Readiness_Government
# Readiness_Government-Scaled
# Readiness_Citizens
# Readiness_Citizens-Scaled
# Readiness_Entrepreneurs
# Readiness_Entrepreneurs-Scaled
# Readiness-Rank
# Datasets_Innovation
# Datasets_Social_Policy
# Datasets_Accountability
# Datasets_Average
# Datasets_Normalised
# Implementation.1
# Implementation-Scaled.1
# Implementation-Rank
# Impact_Political
# Impact_Political-Scaled
# Impact_Social
# Impact_Social-Scaled
# Impact_Economic
# Impact_Economic-Scaled
# HDI
# G20
# G7
# GDP-Per-Capita-Current-USD
# 2013-Rank
# 2013-ODB-Scaled
# ODB Change
# Rank Change
# Cluster

# %%
quan
# Out:
# ['Year',
#  'ODB-Rank',
#  'ODB-Score',
#  'Readiness',
#  'Implementation',
#  'Impact',
#  'ODB-Scaled',
#  'Readiness-Scaled',
#  'Implementation-Scaled',
#  'Impact-Scaled',
#  'Readiness_Government',
#  'Readiness_Government-Scaled',
#  'Readiness_Citizens',
#  'Readiness_Citizens-Scaled',
#  'Readiness_Entrepreneurs',
#  'Readiness_Entrepreneurs-Scaled',
#  'Readiness-Rank',
#  'Datasets_Innovation',
#  'Datasets_Social_Policy',
#  'Datasets_Accountability',
#  'Datasets_Average',
#  'Datasets_Normalised',
#  'Implementation.1',
#  'Implementation-Scaled.1',
#  'Implementation-Rank',
#  'Impact_Political',
#  'Impact_Political-Scaled',
#  'Impact_Social',
#  'Impact_Social-Scaled',
#  'Impact_Economic',
#  'Impact_Economic-Scaled',
#  'HDI',
#  'GDP-Per-Capita-Current-USD',
#  '2013-Rank',
#  '2013-ODB-Scaled',
#  'ODB Change',
#  'Rank Change']

# %%
qual
# Out:
# ['Region', 'Income', 'ISO2', 'ISO3', 'Country', 'G20', 'G7', 'Cluster']

# %%
#fn
def quanQual(dataset):
    qual=[]
    quan=[]
    for columnName in dataset.columns:
        print(columnName)
        if(dataset[columnName].dtype=='O'):
            #print("qual")
            qual.append(columnName)
        else:
            #print("quan")
            quan.append(columnName)
    return quan,qual

# %%
quanQual(dataset)
# Out:
# Year
# Region
# Income
# ISO2
# ISO3
# ODB-Rank
# Country
# ODB-Score
# Readiness
# Implementation
# Impact
# ODB-Scaled
# Readiness-Scaled
# Implementation-Scaled
# Impact-Scaled
# Readiness_Government
# Readiness_Government-Scaled
# Readiness_Citizens
# Readiness_Citizens-Scaled
# Readiness_Entrepreneurs
# Readiness_Entrepreneurs-Scaled
# Readiness-Rank
# Datasets_Innovation
# Datasets_Social_Policy
# Datasets_Accountability
# Datasets_Average
# Datasets_Normalised
# Implementation.1
# Implementation-Scaled.1
# Implementation-Rank
# Impact_Political
# Impact_Political-Scaled
# Impact_Social
# Impact_Social-Scaled
# Impact_Economic
# Impact_Economic-Scaled
# HDI
# G20
# G7
# GDP-Per-Capita-Current-USD
# 2013-Rank
# 2013-ODB-Scaled
# ODB Change
# Rank Change
# Cluster
# (['Year',
#   'ODB-Rank',
#   'ODB-Score',
#   'Readiness',
#   'Implementation',
#   'Impact',
#   'ODB-Scaled',
#   'Readiness-Scaled',
#   'Implementation-Scaled',
#   'Impact-Scaled',
#   'Readiness_Government',
#   'Readiness_Government-Scaled',
#   'Readiness_Citizens',
#   'Readiness_Citizens-Scaled',
#   'Readiness_Entrepreneurs',
#   'Readiness_Entrepreneurs-Scaled',
#   'Readiness-Rank',
#   'Datasets_Innovation',
#   'Datasets_Social_Policy',
#   'Datasets_Accountability',
#   'Datasets_Average',
#   'Datasets_Normalised',
#   'Implementation.1',
#   'Implementation-Scaled.1',
#   'Implementation-Rank',
#   'Impact_Political',
#   'Impact_Political-Scaled',
#   'Impact_Social',
#   'Impact_Social-Scaled',
#   'Impact_Economic',
#   'Impact_Economic-Scaled',
#   'HDI',
#   'GDP-Per-Capita-Current-USD',
#   '2013-Rank',
#   '2013-ODB-Scaled',
#   'ODB Change',
#   'Rank Change'],
#  ['Region', 'Income', 'ISO2', 'ISO3', 'Country', 'G20', 'G7', 'Cluster'])

# %%
quan,qual=quanQual(dataset)
# Out:
# Year
# Region
# Income
# ISO2
# ISO3
# ODB-Rank
# Country
# ODB-Score
# Readiness
# Implementation
# Impact
# ODB-Scaled
# Readiness-Scaled
# Implementation-Scaled
# Impact-Scaled
# Readiness_Government
# Readiness_Government-Scaled
# Readiness_Citizens
# Readiness_Citizens-Scaled
# Readiness_Entrepreneurs
# Readiness_Entrepreneurs-Scaled
# Readiness-Rank
# Datasets_Innovation
# Datasets_Social_Policy
# Datasets_Accountability
# Datasets_Average
# Datasets_Normalised
# Implementation.1
# Implementation-Scaled.1
# Implementation-Rank
# Impact_Political
# Impact_Political-Scaled
# Impact_Social
# Impact_Social-Scaled
# Impact_Economic
# Impact_Economic-Scaled
# HDI
# G20
# G7
# GDP-Per-Capita-Current-USD
# 2013-Rank
# 2013-ODB-Scaled
# ODB Change
# Rank Change
# Cluster

# %%
quan
# Out:
# ['Year',
#  'ODB-Rank',
#  'ODB-Score',
#  'Readiness',
#  'Implementation',
#  'Impact',
#  'ODB-Scaled',
#  'Readiness-Scaled',
#  'Implementation-Scaled',
#  'Impact-Scaled',
#  'Readiness_Government',
#  'Readiness_Government-Scaled',
#  'Readiness_Citizens',
#  'Readiness_Citizens-Scaled',
#  'Readiness_Entrepreneurs',
#  'Readiness_Entrepreneurs-Scaled',
#  'Readiness-Rank',
#  'Datasets_Innovation',
#  'Datasets_Social_Policy',
#  'Datasets_Accountability',
#  'Datasets_Average',
#  'Datasets_Normalised',
#  'Implementation.1',
#  'Implementation-Scaled.1',
#  'Implementation-Rank',
#  'Impact_Political',
#  'Impact_Political-Scaled',
#  'Impact_Social',
#  'Impact_Social-Scaled',
#  'Impact_Economic',
#  'Impact_Economic-Scaled',
#  'HDI',
#  'GDP-Per-Capita-Current-USD',
#  '2013-Rank',
#  '2013-ODB-Scaled',
#  'ODB Change',
#  'Rank Change']

# %%
qual
# Out:
# ['Region', 'Income', 'ISO2', 'ISO3', 'Country', 'G20', 'G7', 'Cluster']
